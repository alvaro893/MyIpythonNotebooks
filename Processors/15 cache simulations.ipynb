# %% [markdown]
# # 15 cache simulations
# colors in the plot are:
# - blue 4K
# - green 16K
# - red 64K

# %%
from __future__ import division
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#associative values tuple
associative = (1,2,4,8)

# miss rate values
gcctrace4 = (0.0516, 0.0367,0.0298,0.0263)
gcctrace16 = (0.0213, 0.0171,0.0164,0.0161)
gcctrace64 = (0.003939,0.003714,0.003691,0.003629)

plot(associative, gcctrace4)
plot(associative, gcctrace16)
plot(associative, gcctrace64)
title("file: gcc.trace", fontsize=16)
xlabel("Associativity")
ylabel("Miss rate")

# %%
gziptrace4 = (0.332055,0.332030,0.331936,0.331947)
gziptrace16 = (0.331789, 0.331801, 0.331795, 0.331791)
gziptrace64 = (0.331758, 0.331762, 0.331753, 0.331760)

plot(associative, gziptrace4)
plot(associative, gziptrace16)
plot(associative, gziptrace64)
title("file: gzip.trace", fontsize=16)
xlabel("Associativity")
ylabel("Miss rate")

# %%
mcftrace4 = (0.248021, 0.248023, 0.247913, 0.247901)
mcftrace16 = (0.247721, 0.247685, 0.247719, 0.247708)
mcftrace64 = (0.247636, 0.247630, 0.247630, 0.247645)

plot(associative, mcftrace4)
plot(associative, mcftrace16)
plot(associative, mcftrace64)
title("file: mcf.trace", fontsize=16)
xlabel("Associativity")
ylabel("Miss rate")

# %%
swimtrace4 = (0.053329, 0.050225, 0.043349, 0.042158)
swimtrace16 = (0.028916, 0.026086, 0.025769, 0.025782)
swimtrace64 = (0.022293, 0.022454, 0.022504, 0.022283)

plot(associative, swimtrace4)
plot(associative, swimtrace16)
plot(associative, swimtrace64)
title("file: swim.trace", fontsize=16)
xlabel("Associativity")
ylabel("Miss rate")

# %%
twolftrace4 = (0.045754, 0.015447, 0.010671, 0.008512)
twolftrace16 = (0.003939,  0.003714, 0.003691,  0.00362)
twolftrace64 = (0.003939, 0.003714, 0.003691, 0.003629)

plot(associative, twolftrace4)
plot(associative, twolftrace16)
plot(associative, twolftrace64)
title("file: twol.ftrace", fontsize=16)
xlabel("Associativity")
ylabel("Miss rate")
